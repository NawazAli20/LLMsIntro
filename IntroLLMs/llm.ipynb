# %%
import os 
from dotenv import load_dotenv
load_dotenv() 
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model(model="groq/compound", model_provider="Groq")
model
# Out:
# ChatGroq(metadata={'lc_versions': {'langchain-core': '1.4.8', 'langchain': '1.3.11'}}, output_version=None, profile={'name': 'Compound', 'release_date': '2025-09-04', 'last_updated': '2025-09-04', 'open_weights': False, 'max_input_tokens': 131072, 'max_output_tokens': 8192, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'attachment': False, 'temperature': True}, client=<groq.resources.chat.completions.Completions object at 0x11279ea50>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x11279f380>, model_name='groq/compound', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %%
model.invoke("Hi there!")
# Out:
# AIMessage(content='Hello! How can I help you today?', additional_kwargs={'reasoning_content': '<Think>\n\n</Think>'}, response_metadata={'token_usage': {'completion_tokens': 35, 'prompt_tokens': 236, 'total_tokens': 271, 'completion_time': 0.075544, 'completion_tokens_details': None, 'prompt_time': 0.009883, 'prompt_tokens_details': None, 'queue_time': 0.5131, 'total_time': 0.085427}, 'model_name': 'groq/compound', 'system_fingerprint': None, 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f2127-1687-7f32-af1c-3879bcfb1208-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 236, 'output_tokens': 35, 'total_tokens': 271})
